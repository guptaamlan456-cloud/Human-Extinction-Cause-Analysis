# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# # Machine Learning Prediction

# %%
df = pd.read_csv("data/final_dataset.csv")

df.head()
# Out:
#    year           co2  temp_anomaly  conflict_deaths  ai_publications  \
# 0  2016  3.539283e+10      1.008333            90624           574316
# 1  2017  3.597461e+10      0.914167            72023           640509
# 2  2018  3.673400e+10      0.847500            55031           787932
# 3  2019  3.708657e+10      0.978333            52610           967369
# 4  2020  3.515823e+10      1.005833            73228          1139600
#
#    ai_capability  conflict_index  climate_pressure  co2_pressure  ai_safety  \
# 0       0.000000        1.694912          3.690249      0.681907   1.506744
# 1       0.580745        0.865558          1.529637      2.372956   2.120638
# 2       1.874163        0.107944          0.000000      4.580275   4.321720
# 3       3.448456        0.000000          3.001912      5.605069   4.304960
# 4       4.959528        0.919285          3.632887      0.000000   5.026170
#
#    risk_score
# 0    0.777945
# 1    0.326682
# 2   -0.155545
# 3    1.076361
# ...

# %%
X = df[["year"]]
y = df["risk_score"]
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
future_years = pd.DataFrame({
    "year": [2025, 2026, 2027, 2028, 2029]
})

predictions = model.predict(future_years)

future_df = future_years.copy()
future_df["predicted_risk"] = predictions

future_df


plt.plot(df["year"], df["risk_score"], label="Historical")
plt.plot(future_df["year"], future_df["predicted_risk"], label="Predicted", linestyle="--")

plt.legend()
plt.xlabel("Year")
plt.ylabel("Risk Score")

plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

features = df[[
    "ai_capability",
    "conflict_index",
    "climate_pressure",
    "co2_pressure",
    "ai_safety"
]]

target = df["risk_score"]

model = RandomForestRegressor(random_state=42)
model.fit(features, target)
# Out:
# RandomForestRegressor(random_state=42)

# %%
importance = model.feature_importances_

feature_importance = pd.DataFrame({
    "feature": features.columns,
    "importance": importance
}).sort_values(by="importance", ascending=False)

feature_importance
# Out:
#             feature  importance
# 0     ai_capability    0.304805
# 3      co2_pressure    0.271364
# 4         ai_safety    0.182487
# 1    conflict_index    0.181778
# 2  climate_pressure    0.059567
